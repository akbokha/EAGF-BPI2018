# %%
import pandas as pd
import numpy as np

# %%
source_dir = '../data/proc/'
dest_dir = '../data/undesired_outcomes_pred/'
extension = '.csv'

# %%
elog = pd.read_csv(source_dir.__add__('elog.csv'))

# %%
pd.options.display.max_columns = 100

# %%
elog.head(10)
# Out:
#             Case ID                                     Activity Resource  \
# 0  8b99873a6136cfa6  Payment application-Application-mail income      NaN
# 1  8b99873a6136cfa6   Payment application-Application-mail valid      NaN
# 2  8b99873a6136cfa6      Entitlement application-Main-mail valid      NaN
# 3  8b99873a6136cfa6      Entitlement application-Main-mail valid      NaN
# 4  8b99873a6136cfa6              Parcel document-Main-initialize   fb5fa8
# 5  8b99873a6136cfa6              Control summary-Main-initialize   fb5fa8
# 6  8b99873a6136cfa6           Control summary-Main-begin editing   fb5fa8
# 7  8b99873a6136cfa6          Control summary-Main-finish editing   fb5fa8
# 8  8b99873a6136cfa6           Parcel document-Main-begin editing   dde669
# 9  8b99873a6136cfa6                    Parcel document-Main-save   dde669
#
#         Complete Timestamp       Variant  Variant index  \
# 0  2015/05/08 00:00:00.000  Variant 1832           1832
# 1  2015/05/08 00:00:00.000  Variant 1832           1832
# 2  2015/05/08 00:00:00.000  Variant 1832           1832
# 3  2015/05/08 00:00:00.000  Variant 1832           1832
# 4  2015/06/10 11:16:28.000  Variant 1832           1832
# 5  2015/06/10 11:16:29.000  Variant 1832           1832
# 6  2015/06/10 11:16:29.000  Variant 1832           1832
# 7  2015/06/10 11:16:29.000  Variant 1832           1832
# 8  2015/06/15 13:01:05.000  Variant 1832           1832
# 9  2015/06/15 13:01:25.000  Variant 1832           1832
#
#    (case) amount_applied0  (case) amount_applied1  (case) amount_applied2  \
# 0                  960.35                     NaN                     NaN
# 1                  960.35                     NaN                     NaN
# 2                  960.35                     NaN                     NaN
# 3                  960.35                     NaN                     NaN
# 4                  960.35                     NaN                     NaN
# 5                  960.35                     NaN                     NaN
# 6                  960.35                     NaN                     NaN
# 7                  960.35                     NaN                     NaN
# 8                  960.35                     NaN                     NaN
# 9                  960.35                     NaN                     NaN
#
#    (case) amount_applied3  (case) applicant (case) application  (case) area  \
# 0                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 1                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 2                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 3                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 4                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 5                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 6                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 7                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 8                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
# 9                     NaN  b3b1bafcf8a5c359   8b99873a6136cfa6       2.6994
#
#    (case) basic payment  (case) cross_compliance (case) department  \
# 0                  True                      0.0                e7
# 1                  True                      0.0                e7
# 2                  True                      0.0                e7
# 3                  True                      0.0                e7
# 4                  True                      0.0                e7
# 5                  True                      0.0                e7
# 6                  True                      0.0                e7
# 7                  True                      0.0                e7
# 8                  True                      0.0                e7
# 9                  True                      0.0                e7
#
#    (case) greening  (case) number_parcels  (case) payment_actual0  \
# 0             True                      3                  960.35
# 1             True                      3                  960.35
# 2             True                      3                  960.35
# 3             True                      3                  960.35
# 4             True                      3                  960.35
# 5             True                      3                  960.35
# 6             True                      3                  960.35
# 7             True                      3                  960.35
# 8             True                      3                  960.35
# 9             True                      3                  960.35
#
#    (case) payment_actual1  (case) payment_actual2  (case) payment_actual3  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
# 5                     NaN                     NaN                     NaN
# 6                     NaN                     NaN                     NaN
# 7                     NaN                     NaN                     NaN
# 8                     NaN                     NaN                     NaN
# 9                     NaN                     NaN                     NaN
#
#    (case) penalty_ABP  (case) penalty_AGP  (case) penalty_AJLP  \
# 0               False               False                False
# 1               False               False                False
# 2               False               False                False
# 3               False               False                False
# 4               False               False                False
# 5               False               False                False
# 6               False               False                False
# 7               False               False                False
# 8               False               False                False
# 9               False               False                False
#
#    (case) penalty_AUVP  (case) penalty_AVBP  (case) penalty_AVGP  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
# 5                False                False                False
# 6                False                False                False
# 7                False                False                False
# 8                False                False                False
# 9                False                False                False
#
#    (case) penalty_AVJLP  (case) penalty_AVUVP  (case) penalty_B16  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
# 3                 False                 False               False
# 4                 False                 False               False
# 5                 False                 False               False
# 6                 False                 False               False
# 7                 False                 False               False
# 8                 False                 False               False
# 9                 False                 False               False
#
#    (case) penalty_B2  (case) penalty_B3  (case) penalty_B4  (case) penalty_B5  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
# 5              False              False              False              False
# 6              False              False              False              False
# 7              False              False              False              False
# 8              False              False              False              False
# 9              False              False              False              False
#
#    (case) penalty_B5F  (case) penalty_B6  (case) penalty_BGK  \
# 0               False              False               False
# 1               False              False               False
# 2               False              False               False
# 3               False              False               False
# 4               False              False               False
# 5               False              False               False
# 6               False              False               False
# 7               False              False               False
# 8               False              False               False
# 9               False              False               False
#
#    (case) penalty_BGKV  (case) penalty_BGP  (case) penalty_C16  \
# 0                False               False               False
# 1                False               False               False
# 2                False               False               False
# 3                False               False               False
# 4                False               False               False
# 5                False               False               False
# 6                False               False               False
# 7                False               False               False
# 8                False               False               False
# 9                False               False               False
#
#    (case) penalty_C4  (case) penalty_C9  (case) penalty_CC  \
# 0              False              False              False
# 1              False              False              False
# 2              False              False              False
# 3              False              False              False
# 4              False              False              False
# 5              False              False              False
# 6              False              False              False
# 7              False              False              False
# 8              False              False              False
# 9              False              False              False
#
#    (case) penalty_GP1  (case) penalty_JLP1  (case) penalty_JLP2  \
# 0               False                False                False
# 1               False                False                False
# 2               False                False                False
# 3               False                False                False
# 4               False                False                False
# 5               False                False                False
# 6               False                False                False
# 7               False                False                False
# 8               False                False                False
# 9               False                False                False
#
#    (case) penalty_JLP3  (case) penalty_JLP5  (case) penalty_JLP6  \
# 0                False                False                False
# 1                False                False                False
# 2                False                False                False
# 3                False                False                False
# 4                False                False                False
# 5                False                False                False
# 6                False                False                False
# 7                False                False                False
# 8                False                False                False
# 9                False                False                False
#
#    (case) penalty_JLP7  (case) penalty_V5  (case) penalty_amount0  \
# 0                False              False                     0.0
# 1                False              False                     0.0
# 2                False              False                     0.0
# 3                False              False                     0.0
# 4                False              False                     0.0
# 5                False              False                     0.0
# 6                False              False                     0.0
# 7                False              False                     0.0
# 8                False              False                     0.0
# 9                False              False                     0.0
#
#    (case) penalty_amount1  (case) penalty_amount2  (case) penalty_amount3  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
# 5                     NaN                     NaN                     NaN
# 6                     NaN                     NaN                     NaN
# 7                     NaN                     NaN                     NaN
# 8                     NaN                     NaN                     NaN
# 9                     NaN                     NaN                     NaN
#
#    (case) program-id  (case) redistribution  (case) rejected  \
# 0                215                   True            False
# 1                215                   True            False
# 2                215                   True            False
# 3                215                   True            False
# 4                215                   True            False
# 5                215                   True            False
# 6                215                   True            False
# 7                215                   True            False
# 8                215                   True            False
# 9                215                   True            False
#
#    (case) risk_factor  (case) selected_manually  (case) selected_random  \
# 0                 1.0                     False                   False
# 1                 1.0                     False                   False
# 2                 1.0                     False                   False
# 3                 1.0                     False                   False
# 4                 1.0                     False                   False
# 5                 1.0                     False                   False
# 6                 1.0                     False                   False
# 7                 1.0                     False                   False
# 8                 1.0                     False                   False
# 9                 1.0                     False                   False
#
#    (case) selected_risk  (case) small farmer  (case) year  \
# 0                 False                 True         2015
# 1                 False                 True         2015
# 2                 False                 True         2015
# 3                 False                 True         2015
# 4                 False                 True         2015
# 5                 False                 True         2015
# 6                 False                 True         2015
# 7                 False                 True         2015
# 8                 False                 True         2015
# 9                 False                 True         2015
#
#    (case) young farmer        activity    concept:name             docid  \
# 0                False     mail income     mail income  ffc0054364e897d9
# 1                False      mail valid      mail valid  ffc0054364e897d9
# 2                False      mail valid      mail valid  ffc005428239d50b
# 3                False      mail valid      mail valid  ffc005428239d50b
# 4                False      initialize      initialize  ff000537695e5fe8
# 5                False      initialize      initialize  ff000537695e6031
# 6                False   begin editing   begin editing  ff000537695e6031
# 7                False  finish editing  finish editing  ff000537695e6031
# 8                False   begin editing   begin editing  ff000537695e5fe8
# 9                False            save            save  ff000537695e5fe8
#
#                    doctype           eventid lifecycle:transition  note  \
# 0      Payment application               NaN             complete  none
# 1      Payment application               NaN             complete  none
# 2  Entitlement application               NaN             complete  none
# 3  Entitlement application               NaN             complete  none
# 4          Parcel document  ff000537695e5fe8             complete  none
# 5          Control summary  ff000537695e6030             complete  none
# 6          Control summary  ff000537695e6038             complete  none
# 7          Control summary  ff000537695e6038             complete  none
# 8          Parcel document  ff000537d0074090             complete  none
# 9          Parcel document  ff000537d00740a0             complete  none
#
#     subprocess  success
# 0  Application     True
# 1  Application     True
# 2         Main     True
# 3         Main     True
# 4         Main     True
# 5         Main     True
# 6         Main     True
# 7         Main     True
# 8         Main     True
# 9         Main     True

# %%
elog.tail(10)
# Out:
#                   Case ID                                         Activity  \
# 2514256  ad5dfa0b929735be        Payment application-Application-calculate
# 2514257  ad5dfa0b929735be   Payment application-Application-finish editing
# 2514258  ad5dfa0b929735be    Payment application-Application-begin editing
# 2514259  ad5dfa0b929735be        Payment application-Application-calculate
# 2514260  ad5dfa0b929735be   Payment application-Application-finish editing
# 2514261  ad5dfa0b929735be           Payment application-Application-decide
# 2514262  ad5dfa0b929735be    Payment application-Application-begin payment
# 2514263  ad5dfa0b929735be  Payment application-Application-insert document
# 2514264  ad5dfa0b929735be  Payment application-Application-insert document
# 2514265  ad5dfa0b929735be   Payment application-Application-finish payment
#
#                        Resource       Complete Timestamp        Variant  \
# 2514256                  727350  2017/12/06 17:49:44.350  Variant 28923
# 2514257                  727350  2017/12/06 17:49:45.195  Variant 28923
# 2514258                  727350  2017/12/09 00:49:01.751  Variant 28923
# 2514259                  727350  2017/12/09 00:49:12.817  Variant 28923
# 2514260                  727350  2017/12/09 00:49:14.987  Variant 28923
# 2514261                  155add  2017/12/11 10:26:39.692  Variant 28923
# 2514262                    DP-Z  2017/12/15 16:00:12.252  Variant 28923
# 2514263  Notification automaton  2017/12/15 19:19:04.499  Variant 28923
# 2514264  Notification automaton  2017/12/20 09:02:30.380  Variant 28923
# 2514265                    DP-Z  2018/01/05 14:45:52.100  Variant 28923
#
#          Variant index  (case) amount_applied0  (case) amount_applied1  \
# 2514256          28923                 5117.97                     NaN
# 2514257          28923                 5117.97                     NaN
# 2514258          28923                 5117.97                     NaN
# 2514259          28923                 5117.97                     NaN
# 2514260          28923                 5117.97                     NaN
# 2514261          28923                 5117.97                     NaN
# 2514262          28923                 5117.97                     NaN
# 2514263          28923                 5117.97                     NaN
# 2514264          28923                 5117.97                     NaN
# 2514265          28923                 5117.97                     NaN
#
#          (case) amount_applied2  (case) amount_applied3  (case) applicant  \
# 2514256                     NaN                     NaN  3a96cda3a6b0f35f
# 2514257                     NaN                     NaN  3a96cda3a6b0f35f
# 2514258                     NaN                     NaN  3a96cda3a6b0f35f
# 2514259                     NaN                     NaN  3a96cda3a6b0f35f
# 2514260                     NaN                     NaN  3a96cda3a6b0f35f
# 2514261                     NaN                     NaN  3a96cda3a6b0f35f
# 2514262                     NaN                     NaN  3a96cda3a6b0f35f
# 2514263                     NaN                     NaN  3a96cda3a6b0f35f
# 2514264                     NaN                     NaN  3a96cda3a6b0f35f
# 2514265                     NaN                     NaN  3a96cda3a6b0f35f
#
#         (case) application  (case) area  (case) basic payment  \
# 2514256   ad5dfa0b929735be      15.2806                  True
# 2514257   ad5dfa0b929735be      15.2806                  True
# 2514258   ad5dfa0b929735be      15.2806                  True
# 2514259   ad5dfa0b929735be      15.2806                  True
# 2514260   ad5dfa0b929735be      15.2806                  True
# 2514261   ad5dfa0b929735be      15.2806                  True
# 2514262   ad5dfa0b929735be      15.2806                  True
# 2514263   ad5dfa0b929735be      15.2806                  True
# 2514264   ad5dfa0b929735be      15.2806                  True
# 2514265   ad5dfa0b929735be      15.2806                  True
#
#          (case) cross_compliance (case) department  (case) greening  \
# 2514256                      0.0                6b             True
# 2514257                      0.0                6b             True
# 2514258                      0.0                6b             True
# 2514259                      0.0                6b             True
# 2514260                      0.0                6b             True
# 2514261                      0.0                6b             True
# 2514262                      0.0                6b             True
# 2514263                      0.0                6b             True
# 2514264                      0.0                6b             True
# 2514265                      0.0                6b             True
#
#          (case) number_parcels  (case) payment_actual0  \
# 2514256                      6                 5116.99
# 2514257                      6                 5116.99
# 2514258                      6                 5116.99
# 2514259                      6                 5116.99
# 2514260                      6                 5116.99
# 2514261                      6                 5116.99
# 2514262                      6                 5116.99
# 2514263                      6                 5116.99
# 2514264                      6                 5116.99
# 2514265                      6                 5116.99
#
#          (case) payment_actual1  (case) payment_actual2  \
# 2514256                     NaN                     NaN
# 2514257                     NaN                     NaN
# 2514258                     NaN                     NaN
# 2514259                     NaN                     NaN
# 2514260                     NaN                     NaN
# 2514261                     NaN                     NaN
# 2514262                     NaN                     NaN
# 2514263                     NaN                     NaN
# 2514264                     NaN                     NaN
# 2514265                     NaN                     NaN
#
#          (case) payment_actual3  (case) penalty_ABP  (case) penalty_AGP  \
# 2514256                     NaN               False               False
# 2514257                     NaN               False               False
# 2514258                     NaN               False               False
# 2514259                     NaN               False               False
# 2514260                     NaN               False               False
# 2514261                     NaN               False               False
# 2514262                     NaN               False               False
# 2514263                     NaN               False               False
# 2514264                     NaN               False               False
# 2514265                     NaN               False               False
#
#          (case) penalty_AJLP  (case) penalty_AUVP  (case) penalty_AVBP  \
# 2514256                False                False                False
# 2514257                False                False                False
# 2514258                False                False                False
# 2514259                False                False                False
# 2514260                False                False                False
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_AVGP  (case) penalty_AVJLP  (case) penalty_AVUVP  \
# 2514256                False                 False                 False
# 2514257                False                 False                 False
# 2514258                False                 False                 False
# 2514259                False                 False                 False
# 2514260                False                 False                 False
# 2514261                False                 False                 False
# 2514262                False                 False                 False
# 2514263                False                 False                 False
# 2514264                False                 False                 False
# 2514265                False                 False                 False
#
#          (case) penalty_B16  (case) penalty_B2  (case) penalty_B3  \
# 2514256               False              False              False
# 2514257               False              False              False
# 2514258               False              False              False
# 2514259               False              False              False
# 2514260               False              False              False
# 2514261               False              False              False
# 2514262               False              False              False
# 2514263               False              False              False
# 2514264               False              False              False
# 2514265               False              False              False
#
#          (case) penalty_B4  (case) penalty_B5  (case) penalty_B5F  \
# 2514256              False              False               False
# 2514257              False              False               False
# 2514258              False              False               False
# 2514259              False              False               False
# 2514260              False              False               False
# 2514261              False              False               False
# 2514262              False              False               False
# 2514263              False              False               False
# 2514264              False              False               False
# 2514265              False              False               False
#
#          (case) penalty_B6  (case) penalty_BGK  (case) penalty_BGKV  \
# 2514256              False               False                False
# 2514257              False               False                False
# 2514258              False               False                False
# 2514259              False               False                False
# 2514260              False               False                False
# 2514261              False               False                False
# 2514262              False               False                False
# 2514263              False               False                False
# 2514264              False               False                False
# 2514265              False               False                False
#
#          (case) penalty_BGP  (case) penalty_C16  (case) penalty_C4  \
# 2514256               False               False              False
# 2514257               False               False              False
# 2514258               False               False              False
# 2514259               False               False              False
# 2514260               False               False              False
# 2514261               False               False              False
# 2514262               False               False              False
# 2514263               False               False              False
# 2514264               False               False              False
# 2514265               False               False              False
#
#          (case) penalty_C9  (case) penalty_CC  (case) penalty_GP1  \
# 2514256              False              False               False
# 2514257              False              False               False
# 2514258              False              False               False
# 2514259              False              False               False
# 2514260              False              False               False
# 2514261              False              False               False
# 2514262              False              False               False
# 2514263              False              False               False
# 2514264              False              False               False
# 2514265              False              False               False
#
#          (case) penalty_JLP1  (case) penalty_JLP2  (case) penalty_JLP3  \
# 2514256                False                False                False
# 2514257                False                False                False
# 2514258                False                False                False
# 2514259                False                False                False
# 2514260                False                False                False
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_JLP5  (case) penalty_JLP6  (case) penalty_JLP7  \
# 2514256                False                False                False
# 2514257                False                False                False
# 2514258                False                False                False
# 2514259                False                False                False
# 2514260                False                False                False
# 2514261                False                False                False
# 2514262                False                False                False
# 2514263                False                False                False
# 2514264                False                False                False
# 2514265                False                False                False
#
#          (case) penalty_V5  (case) penalty_amount0  (case) penalty_amount1  \
# 2514256              False                     0.0                     NaN
# 2514257              False                     0.0                     NaN
# 2514258              False                     0.0                     NaN
# 2514259              False                     0.0                     NaN
# 2514260              False                     0.0                     NaN
# 2514261              False                     0.0                     NaN
# 2514262              False                     0.0                     NaN
# 2514263              False                     0.0                     NaN
# 2514264              False                     0.0                     NaN
# 2514265              False                     0.0                     NaN
#
#          (case) penalty_amount2  (case) penalty_amount3  (case) program-id  \
# 2514256                     NaN                     NaN                215
# 2514257                     NaN                     NaN                215
# 2514258                     NaN                     NaN                215
# 2514259                     NaN                     NaN                215
# 2514260                     NaN                     NaN                215
# 2514261                     NaN                     NaN                215
# 2514262                     NaN                     NaN                215
# 2514263                     NaN                     NaN                215
# 2514264                     NaN                     NaN                215
# 2514265                     NaN                     NaN                215
#
#          (case) redistribution  (case) rejected  (case) risk_factor  \
# 2514256                   True            False                 1.0
# 2514257                   True            False                 1.0
# 2514258                   True            False                 1.0
# 2514259                   True            False                 1.0
# 2514260                   True            False                 1.0
# 2514261                   True            False                 1.0
# 2514262                   True            False                 1.0
# 2514263                   True            False                 1.0
# 2514264                   True            False                 1.0
# 2514265                   True            False                 1.0
#
#          (case) selected_manually  (case) selected_random  \
# 2514256                     False                   False
# 2514257                     False                   False
# 2514258                     False                   False
# 2514259                     False                   False
# 2514260                     False                   False
# 2514261                     False                   False
# 2514262                     False                   False
# 2514263                     False                   False
# 2514264                     False                   False
# 2514265                     False                   False
#
#          (case) selected_risk  (case) small farmer  (case) year  \
# 2514256                 False                False         2017
# 2514257                 False                False         2017
# 2514258                 False                False         2017
# 2514259                 False                False         2017
# 2514260                 False                False         2017
# 2514261                 False                False         2017
# 2514262                 False                False         2017
# 2514263                 False                False         2017
# 2514264                 False                False         2017
# 2514265                 False                False         2017
#
#          (case) young farmer         activity     concept:name  \
# 2514256                False        calculate        calculate
# 2514257                False   finish editing   finish editing
# 2514258                False    begin editing    begin editing
# 2514259                False        calculate        calculate
# 2514260                False   finish editing   finish editing
# 2514261                False           decide           decide
# 2514262                False    begin payment    begin payment
# 2514263                False  insert document  insert document
# 2514264                False  insert document  insert document
# 2514265                False   finish payment   finish payment
#
#                     docid              doctype           eventid  \
# 2514256  ff40057d15bb2574  Payment application  ffc00580a8a936f8
# 2514257  ff40057d15bb2574  Payment application  ffc00580a8a93942
# 2514258  ff40057d15bb2574  Payment application  ffc00580defa3156
# 2514259  ff40057d15bb2574  Payment application  ffc00580defa673c
# 2514260  ff40057d15bb2574  Payment application  ffc00580defa72e0
# 2514261  ff40057d15bb2574  Payment application  fec0058107e5cd30
# 2514262  ff40057d15bb2574  Payment application  fec0058167e43520
# 2514263  ff40057d15bb2574  Payment application  fec0058167eadf30
# 2514264  ff40057d15bb2574  Payment application  fe400581c8e49760
# 2514265  ff40057d15bb2574  Payment application  ffc005830b0738e2
#
#         lifecycle:transition                        note   subprocess  success
# 2514256             complete                   automatic  Application     True
# 2514257             complete                   automatic  Application     True
# 2514258             complete                   automatic  Application     True
# 2514259             complete                   automatic  Application     True
# 2514260             complete                   automatic  Application     True
# 2514261             complete                   automatic  Application     True
# 2514262             complete    automatic during payment  Application     True
# 2514263             complete  notification for applicant  Application     True
# 2514264             complete  notification for applicant  Application    False
# 2514265             complete    automatic during payment  Application     True

# %%
elog.columns.values
# Out:
# array(['Case ID', 'Activity', 'Resource', 'Complete Timestamp', 'Variant',
#        'Variant index', '(case) amount_applied0', '(case) amount_applied1',
#        '(case) amount_applied2', '(case) amount_applied3',
#        '(case) applicant', '(case) application', '(case) area',
#        '(case) basic payment', '(case) cross_compliance',
#        '(case) department', '(case) greening', '(case) number_parcels',
#        '(case) payment_actual0', '(case) payment_actual1',
#        '(case) payment_actual2', '(case) payment_actual3',
#        '(case) penalty_ABP', '(case) penalty_AGP', '(case) penalty_AJLP',
#        '(case) penalty_AUVP', '(case) penalty_AVBP', '(case) penalty_AVGP',
#        '(case) penalty_AVJLP', '(case) penalty_AVUVP',
#        '(case) penalty_B16', '(case) penalty_B2', '(case) penalty_B3',
#        '(case) penalty_B4', '(case) penalty_B5', '(case) penalty_B5F',
#        '(case) penalty_B6', '(case) penalty_BGK', '(case) penalty_BGKV',
#        '(case) penalty_BGP', '(case) penalty_C16', '(case) penalty_C4',
#        '(case) penalty_C9', '(case) penalty_CC', '(case) penalty_GP1',
#        '(case) penalty_JLP1', '(case) penalty_JLP2', '(case) penalty_JLP3',
#        '(case) penalty_JLP5', '(case) penalty_JLP6', '(case) penalty_JLP7',
#        '(case) penalty_V5', '(case) penalty_amount0',
#        '(case) penalty_amount1', '(case) penalty_amount2',
#        '(case) penalty_amount3', '(case) program-id',
#        '(case) redistribution', '(case) rejected', '(case) risk_factor',
#        '(case) selected_manually', '(case) selected_random',
#        '(case) selected_risk', '(case) small farmer', '(case) year',
#        '(case) young farmer', 'activity', 'concept:name', 'docid',
#        'doctype', 'eventid', 'lifecycle:transition', 'note', 'subprocess',
#        'success'], dtype=object)

# %%
unique_case_ids = list(set(elog['Case ID'])) 
print("number of unique cases: ", len(unique_case_ids)) # so indeed 43809 cases
# Out:
# number of unique cases:  43809

# %%
unique_applicants = list(set(elog['(case) applicant'])) 
print("number of unique applicants: ", len(unique_applicants)) # so 15938 unique applicants in three years
# Out:
# number of unique applicants:  15938

# %%
elog['Case ID'].equals(elog['(case) application']) # so two columns with same infrormation, delete second one
# Out:
# True

# %%
elog.drop(['(case) application'], axis=1, inplace=True)

# %%
len(set(elog['Variant'])) # no documentaion on this attribute + doesn't encapsulate a lot of information
# Out:
# 28923

# %%
elog.drop(['Variant', 'Variant index'], axis=1, inplace=True)

# %% [markdown]
# ### amount applied processing

# %%
def return_num_changes_applied_amount(x):
    result = 0
    if not (pd.isnull(x['(case) amount_applied1']) or x['(case) amount_applied0'] == x['(case) amount_applied1']):
        result += 1
    if not (pd.isnull(x['(case) amount_applied2']) or x['(case) amount_applied1'] == x['(case) amount_applied2']):
        result += 1
    if not (pd.isnull(x['(case) amount_applied3']) or x['(case) amount_applied2'] == x['(case) amount_applied3']):
        result += 1
    return result

# %%
def return_final_applied_amount(x):
    if not pd.isnull(x['(case) amount_applied3']):
        return x['(case) amount_applied3']
    elif not pd.isnull(x['(case) amount_applied2']):
        return x['(case) amount_applied2']
    elif not pd.isnull(x['(case) amount_applied1']):
        return x['(case) amount_applied1']
    else:
        return x['(case) amount_applied0']

# %%
def return_diff_applied_amount(x):
    if not pd.isnull(x['(case) amount_applied3']):
        return x['(case) amount_applied3'] - x['(case) amount_applied0']
    elif not pd.isnull(x['(case) amount_applied2']):
        return x['(case) amount_applied2'] -x['(case) amount_applied0']
    elif not pd.isnull(x['(case) amount_applied1']):
        return x['(case) amount_applied1'] - x['(case) amount_applied0']
    else:
        return 0

# %%
# elog.loc[elog['(case) amount_applied1'] > 0]

# %%
elog['num changes applied amount'] = elog.apply(return_num_changes_applied_amount, axis=1)

# %%
# random control checks
elog.loc[elog['num changes applied amount'] > 0].sample(3)
elog.loc[elog['num changes applied amount'] > 1].sample(3)
elog.loc[elog['num changes applied amount'] > 2].sample(3)
# Out:
#                   Case ID                                 Activity Resource  \
# 33909    31dc792faebd46d5                Control summary-Main-save   6f6a4e
# 34039    31dc792faebd46d5  Payment application-Objection-calculate   79367e
# 1495086  6dcac1562d4ca766                  Inspection-On-Site-save   7850e8
#
#               Complete Timestamp  (case) amount_applied0  \
# 33909    2015/11/16 08:08:18.000               150960.97
# 34039    2017/11/24 12:49:11.301               150960.97
# 1495086  2016/12/01 10:04:50.930                34769.12
#
#          (case) amount_applied1  (case) amount_applied2  \
# 33909                      0.00               150927.32
# 34039                      0.00               150927.32
# 1495086                34794.71                35254.05
#
#          (case) amount_applied3  (case) applicant  (case) area  \
# 33909                 150959.87  e5a229e3a5f5915f     398.9333
# 34039                 150959.87  e5a229e3a5f5915f     398.9333
# 1495086                35253.72  a5d52351e3091a8d     107.9741
#
#          (case) basic payment  (case) cross_compliance (case) department  \
# 33909                    True                      0.0                6b
# 34039                    True                      0.0                6b
# 1495086                  True                      0.0                d4
#
#          (case) greening  (case) number_parcels  (case) payment_actual0  \
# 33909               True                     96               150537.94
# 34039               True                     96               150537.94
# 1495086             True                     59                29492.92
#
#          (case) payment_actual1  (case) payment_actual2  \
# 33909                      0.00                 -789.85
# 34039                      0.00                 -789.85
# 1495086                 5273.58                 -376.22
#
#          (case) payment_actual3  (case) penalty_ABP  (case) penalty_AGP  \
# 33909                    786.37               False               False
# 34039                    786.37               False               False
# 1495086                 -378.30               False               False
#
#          (case) penalty_AJLP  (case) penalty_AUVP  (case) penalty_AVBP  \
# 33909                  False                False                False
# 34039                  False                False                False
# 1495086                False                False                False
#
#          (case) penalty_AVGP  (case) penalty_AVJLP  (case) penalty_AVUVP  \
# 33909                  False                 False                 False
# 34039                  False                 False                 False
# 1495086                False                 False                 False
#
#          (case) penalty_B16  (case) penalty_B2  (case) penalty_B3  \
# 33909                 False               True              False
# 34039                 False               True              False
# 1495086               False              False              False
#
#          (case) penalty_B4  (case) penalty_B5  (case) penalty_B5F  \
# 33909                False              False               False
# 34039                False              False               False
# 1495086              False               True               False
#
#          (case) penalty_B6  (case) penalty_BGK  (case) penalty_BGKV  \
# 33909                False               False                False
# 34039                False               False                False
# 1495086              False               False                False
#
#          (case) penalty_BGP  (case) penalty_C16  (case) penalty_C4  \
# 33909                 False               False              False
# 34039                 False               False              False
# 1495086               False               False              False
#
#          (case) penalty_C9  (case) penalty_CC  (case) penalty_GP1  \
# 33909                False              False               False
# 34039                False              False               False
# 1495086              False              False               False
#
#          (case) penalty_JLP1  (case) penalty_JLP2  (case) penalty_JLP3  \
# 33909                  False                False                False
# 34039                  False                False                False
# 1495086                False                False                False
#
#          (case) penalty_JLP5  (case) penalty_JLP6  (case) penalty_JLP7  \
# 33909                  False                False                False
# 34039                  False                False                False
# 1495086                False                False                False
#
#          (case) penalty_V5  (case) penalty_amount0  (case) penalty_amount1  \
# 33909                False                  370.61                     0.0
# 34039                False                  370.61                     0.0
# 1495086              False                 2115.09                    42.0
#
#          (case) penalty_amount2  (case) penalty_amount3  (case) program-id  \
# 33909                    450.84                  372.99                215
# 34039                    450.84                  372.99                215
# 1495086                  501.37                  502.08                215
#
#          (case) redistribution  (case) rejected  (case) risk_factor  \
# 33909                     True            False                 1.0
# 34039                     True            False                 1.0
# 1495086                   True            False                 1.0
#
#          (case) selected_manually  (case) selected_random  \
# 33909                       False                   False
# 34039                       False                   False
# 1495086                     False                    True
#
#          (case) selected_risk  (case) small farmer  (case) year  \
# 33909                   False                False         2015
# 34039                   False                False         2015
# 1495086                  True                False         2016
#
#          (case) young farmer   activity concept:name             docid  \
# 33909                  False       save         save  ffc005377e0cf9c3
# 34039                  False  calculate    calculate  ffc0054364e2fcfa
# 1495086                False       save         save  ff000557bf897883
#
#                      doctype           eventid lifecycle:transition  note  \
# 33909        Control summary  ff00054432be2b38             complete  none
# 34039    Payment application  fec0057fa9ba1370             complete  none
# 1495086           Inspection  ff4005633eebca28             complete  none
#
#         subprocess  success  num changes applied amount
# 33909         Main     True                           3
# 34039    Objection     True                           3
# 1495086    On-Site     True                           3

# %%
elog['final applied amount'] = elog.apply(return_final_applied_amount, axis=1)

# %%
elog['diff applied amount'] = elog.apply(return_diff_applied_amount, axis=1)

# %%
elog['applied amount lowered'] = np.where(elog['diff applied amount'] < 0, True, False)

# %%
elog['applied amount changed'] = np.where(~pd.isnull(elog['(case) amount_applied1']), True, False)

# %%
elog.sample(5)
# Out:
#                   Case ID                                       Activity  \
# 681582   d8cd7f8feca42f1b     Entitlement application-Main-begin editing
# 2289001  a9e23b69815f05f2  Payment application-Application-begin editing
# 1751232  29984996c166749e     Geo parcel document-Reported-begin editing
# 1633900  04ccccf49a3c1738  Payment application-Application-begin editing
# 26250    d4ea47ff52de6f2a      Payment application-Application-calculate
#
#         Resource       Complete Timestamp  (case) amount_applied0  \
# 681582    727350  2015/12/02 14:48:53.518                59026.68
# 2289001   727350  2017/11/17 08:24:44.561                 1789.06
# 1751232   727350  2017/12/03 22:37:27.248                 1259.45
# 1633900   727350  2016/11/17 14:44:44.840                12073.30
# 26250     727350  2015/11/23 14:09:49.958                44619.55
#
#          (case) amount_applied1  (case) amount_applied2  \
# 681582                      NaN                     NaN
# 2289001                     NaN                     NaN
# 1751232                     NaN                     NaN
# 1633900                     NaN                     NaN
# 26250                       NaN                     NaN
#
#          (case) amount_applied3  (case) applicant  (case) area  \
# 681582                      NaN  0a8fe5e56246e6ec     196.0668
# 2289001                     NaN  9b429251112ab6b6       5.4582
# 1751232                     NaN  aeea72e0e071f48f       3.8263
# 1633900                     NaN  278bded24fc0d041      41.8506
# 26250                       NaN  c1921459dc4f7786     147.9347
#
#          (case) basic payment  (case) cross_compliance (case) department  \
# 681582                   True                      0.0                d4
# 2289001                  True                      0.0                e7
# 1751232                  True                      0.0                e7
# 1633900                  True                      0.0                e7
# 26250                    True                      0.0                4e
#
#          (case) greening  (case) number_parcels  (case) payment_actual0  \
# 681582              True                     52                58951.55
# 2289001             True                      3                 1789.06
# 1751232             True                      2                 1259.45
# 1633900             True                     21                12077.60
# 26250               True                     33                44586.69
#
#          (case) payment_actual1  (case) payment_actual2  \
# 681582                      NaN                     NaN
# 2289001                     NaN                     NaN
# 1751232                     NaN                     NaN
# 1633900                     NaN                     NaN
# 26250                       NaN                     NaN
#
#          (case) payment_actual3  (case) penalty_ABP  (case) penalty_AGP  \
# 681582                      NaN               False               False
# 2289001                     NaN               False               False
# 1751232                     NaN               False               False
# 1633900                     NaN               False               False
# 26250                       NaN               False               False
#
#          (case) penalty_AJLP  (case) penalty_AUVP  (case) penalty_AVBP  \
# 681582                 False                False                False
# 2289001                False                False                False
# 1751232                False                False                False
# 1633900                False                False                False
# 26250                  False                False                False
#
#          (case) penalty_AVGP  (case) penalty_AVJLP  (case) penalty_AVUVP  \
# 681582                 False                 False                 False
# 2289001                False                 False                 False
# 1751232                False                 False                 False
# 1633900                False                 False                 False
# 26250                  False                 False                 False
#
#          (case) penalty_B16  (case) penalty_B2  (case) penalty_B3  \
# 681582                False               True              False
# 2289001               False              False              False
# 1751232               False              False              False
# 1633900               False              False              False
# 26250                 False               True              False
#
#          (case) penalty_B4  (case) penalty_B5  (case) penalty_B5F  \
# 681582               False              False               False
# 2289001              False              False               False
# 1751232              False              False               False
# 1633900              False              False               False
# 26250                False              False               False
#
#          (case) penalty_B6  (case) penalty_BGK  (case) penalty_BGKV  \
# 681582               False               False                False
# 2289001              False               False                False
# 1751232              False               False                False
# 1633900              False               False                False
# 26250                False               False                False
#
#          (case) penalty_BGP  (case) penalty_C16  (case) penalty_C4  \
# 681582                False               False              False
# 2289001               False               False              False
# 1751232               False               False              False
# 1633900               False               False              False
# 26250                 False               False              False
#
#          (case) penalty_C9  (case) penalty_CC  (case) penalty_GP1  \
# 681582               False              False               False
# 2289001              False              False               False
# 1751232              False              False               False
# 1633900              False              False               False
# 26250                False              False               False
#
#          (case) penalty_JLP1  (case) penalty_JLP2  (case) penalty_JLP3  \
# 681582                 False                False                False
# 2289001                False                False                False
# 1751232                False                False                False
# 1633900                False                False                False
# 26250                  False                False                False
#
#          (case) penalty_JLP5  (case) penalty_JLP6  (case) penalty_JLP7  \
# 681582                 False                False                False
# 2289001                False                False                False
# 1751232                False                False                False
# 1633900                False                False                False
# 26250                  False                False                False
#
#          (case) penalty_V5  (case) penalty_amount0  (case) penalty_amount1  \
# 681582               False                   54.99                     NaN
# 2289001              False                    0.00                     NaN
# 1751232              False                    0.00                     NaN
# 1633900              False                    0.00                     NaN
# 26250                False                   17.83                     NaN
#
#          (case) penalty_amount2  (case) penalty_amount3  (case) program-id  \
# 681582                      NaN                     NaN                215
# 2289001                     NaN                     NaN                215
# 1751232                     NaN                     NaN                215
# 1633900                     NaN                     NaN                215
# 26250                       NaN                     NaN                215
#
#          (case) redistribution  (case) rejected  (case) risk_factor  \
# 681582                    True            False                 1.0
# 2289001                   True            False                 1.0
# 1751232                   True            False                 1.0
# 1633900                   True            False                 1.0
# 26250                     True            False                 1.0
#
#          (case) selected_manually  (case) selected_random  \
# 681582                      False                   False
# 2289001                     False                   False
# 1751232                     False                   False
# 1633900                     False                   False
# 26250                       False                   False
#
#          (case) selected_risk  (case) small farmer  (case) year  \
# 681582                  False                False         2015
# 2289001                 False                False         2017
# 1751232                 False                False         2017
# 1633900                 False                False         2016
# 26250                   False                False         2015
#
#          (case) young farmer       activity   concept:name             docid  \
# 681582                 False  begin editing  begin editing  ffc0054282354e4c
# 2289001                False  begin editing  begin editing  ff40057d15ae94b2
# 1751232                False  begin editing  begin editing  ffc0057062a6ca96
# 1633900                False  begin editing  begin editing  ff00055ed5784041
# 26250                  False      calculate      calculate  ffc0054364e430b1
#
#                          doctype           eventid lifecycle:transition  \
# 681582   Entitlement application  fec0054589a1fe70             complete
# 2289001      Payment application  ffc0057f1a5b25d6             complete
# 1751232      Geo parcel document  ffc005803a3118c4             complete
# 1633900      Payment application  ff800561bd3808d8             complete
# 26250        Payment application  fe800544c2ea6f20             complete
#
#               note   subprocess  success  num changes applied amount  \
# 681582   automatic         Main     True                           0
# 2289001  automatic  Application     True                           0
# 1751232  automatic     Reported     True                           0
# 1633900  automatic  Application     True                           0
# 26250    automatic  Application     True                           0
#
#          final applied amount  diff applied amount  applied amount lowered  \
# 681582               59026.68                  0.0                   False
# 2289001               1789.06                  0.0                   False
# 1751232               1259.45                  0.0                   False
# 1633900              12073.30                  0.0                   False
# 26250                44619.55                  0.0                   False
#
#          applied amount changed
# 681582                    False
# 2289001                   False
# 1751232                   False
# 1633900                   False
# 26250                     False

# %% [markdown]
# ### actual payment processing

# %%
def return_num_changes_actual_amount(x):
    result = 0
    if not (pd.isnull(x['(case) payment_actual1']) or x['(case) payment_actual0'] == x['(case) payment_actual1']):
        result += 1
    if not (pd.isnull(x['(case) payment_actual2']) or x['(case) payment_actual1'] == x['(case) payment_actual2']):
        result += 1
    if not (pd.isnull(x['(case) payment_actual3']) or x['(case) payment_actual2'] == x['(case) payment_actual3']):
        result += 1
    return result

# %%
def return_final_actual_amount(x):
    if not pd.isnull(x['(case) payment_actual3']):
        return x['(case) payment_actual3'] + x['(case) payment_actual2'] + x['(case) payment_actual1'] + x['(case) payment_actual0']
    elif not pd.isnull(x['(case) payment_actual2']):
        return x['(case) payment_actual2'] + x['(case) payment_actual1'] + x['(case) payment_actual0']
    elif not pd.isnull(x['(case) payment_actual1']):
        return x['(case) payment_actual1'] + x['(case) payment_actual0']
    else:
        return x['(case) payment_actual0']

# %%
def return_diff_actual_amount(x):
    if not pd.isnull(x['(case) payment_actual3']):
        return x['(case) payment_actual3'] + x['(case) payment_actual2'] + x['(case) payment_actual1']
    elif not pd.isnull(x['(case) payment_actual2']):
        return x['(case) payment_actual2'] + x['(case) payment_actual1'] 
    elif not pd.isnull(x['(case) payment_actual1']):
        return x['(case) payment_actual1']
    else:
        return 0

# %%
elog['num changes actual amount'] = elog.apply(return_num_changes_actual_amount, axis=1)

# %%
elog['final actual amount'] = elog.apply(return_final_actual_amount, axis=1)

# %%
elog['diff actual amount'] = elog.apply(return_diff_actual_amount, axis=1)

# %%
elog['actual amount lowered'] = np.where(elog['diff actual amount'] < 0, True, False)
elog['actual amount changed'] = np.where(~pd.isnull(elog['(case) payment_actual1']), True, False)
elog['actual amount pay'] = np.where(elog['final actual amount'] < 0, True, False)

# %%
elog.sample(5)
# Out:
#                   Case ID                                     Activity  \
# 426619   d534935f7e7346d6    Department control parcels-Main-performed
# 26770    37167c78e29fc39d  Entitlement application-Main-finish editing
# 2447701  47a9d2916147641e    Payment application-Application-calculate
# 95993    9d0a2dd9850c46d9                    Control summary-Main-save
# 1485214  6a94da441c53743f  Geo parcel document-Declared-finish editing
#
#                      Resource       Complete Timestamp  \
# 426619                 727350  2015/09/15 17:19:41.000
# 26770    Processing automaton  2015/10/31 05:46:58.965
# 2447701                727350  2017/12/08 23:49:56.588
# 95993                  97d224  2015/09/09 17:13:23.000
# 1485214                dee71b  2016/08/23 11:45:26.246
#
#          (case) amount_applied0  (case) amount_applied1  \
# 426619                 11333.40                     NaN
# 26770                   1505.57                     NaN
# 2447701                15636.07                     NaN
# 95993                  62184.06                     NaN
# 1485214                 3926.42                     NaN
#
#          (case) amount_applied2  (case) amount_applied3  (case) applicant  \
# 426619                      NaN                     NaN  40b734534bfa6be1
# 26770                       NaN                     NaN  894bc63febc97473
# 2447701                     NaN                     NaN  a4fba2a741353793
# 95993                       NaN                     NaN  1ed3d77c9b1d5154
# 1485214                     NaN                     NaN  c543a272c6221a6d
#
#          (case) area  (case) basic payment  (case) cross_compliance  \
# 426619       33.5562                  True                      0.0
# 26770         4.1348                  True                      0.0
# 2447701      48.6071                  True                      0.0
# 95993       204.2089                  True                      0.0
# 1485214      11.6215                  True                      0.0
#
#         (case) department  (case) greening  (case) number_parcels  \
# 426619                 6b             True                     17
# 26770                  e7             True                      2
# 2447701                d4             True                     15
# 95993                  e7             True                     29
# 1485214                4e             True                      5
#
#          (case) payment_actual0  (case) payment_actual1  \
# 426619                 11330.13                     NaN
# 26770                   1359.26                     NaN
# 2447701                15596.69                     NaN
# 95993                  62080.09                     NaN
# 1485214                 3927.18                     NaN
#
#          (case) payment_actual2  (case) payment_actual3  (case) penalty_ABP  \
# 426619                      NaN                     NaN               False
# 26770                       NaN                     NaN               False
# 2447701                     NaN                     NaN               False
# 95993                       NaN                     NaN               False
# 1485214                     NaN                     NaN               False
#
#          (case) penalty_AGP  (case) penalty_AJLP  (case) penalty_AUVP  \
# 426619                False                False                False
# 26770                 False                False                False
# 2447701               False                False                False
# 95993                 False                False                False
# 1485214               False                False                False
#
#          (case) penalty_AVBP  (case) penalty_AVGP  (case) penalty_AVJLP  \
# 426619                 False                False                 False
# 26770                  False                False                 False
# 2447701                False                False                 False
# 95993                  False                False                 False
# 1485214                False                False                 False
#
#          (case) penalty_AVUVP  (case) penalty_B16  (case) penalty_B2  \
# 426619                  False               False              False
# 26770                   False               False              False
# 2447701                 False               False               True
# 95993                   False               False               True
# 1485214                 False               False              False
#
#          (case) penalty_B3  (case) penalty_B4  (case) penalty_B5  \
# 426619               False              False              False
# 26770                 True              False              False
# 2447701              False              False              False
# 95993                False              False              False
# 1485214              False              False              False
#
#          (case) penalty_B5F  (case) penalty_B6  (case) penalty_BGK  \
# 426619                False              False               False
# 26770                 False              False               False
# 2447701               False              False               False
# 95993                 False              False               False
# 1485214               False              False               False
#
#          (case) penalty_BGKV  (case) penalty_BGP  (case) penalty_C16  \
# 426619                 False               False               False
# 26770                  False               False               False
# 2447701                False               False               False
# 95993                  False               False               False
# 1485214                False               False               False
#
#          (case) penalty_C4  (case) penalty_C9  (case) penalty_CC  \
# 426619               False              False              False
# 26770                False              False              False
# 2447701              False              False              False
# 95993                False              False              False
# 1485214              False              False              False
#
#          (case) penalty_GP1  (case) penalty_JLP1  (case) penalty_JLP2  \
# 426619                False                False                False
# 26770                 False                False                False
# 2447701               False                False                False
# 95993                 False                False                False
# 1485214               False                False                False
#
#          (case) penalty_JLP3  (case) penalty_JLP5  (case) penalty_JLP6  \
# 426619                 False                False                False
# 26770                  False                False                False
# 2447701                False                False                False
# 95993                  False                False                False
# 1485214                False                False                False
#
#          (case) penalty_JLP7  (case) penalty_V5  (case) penalty_amount0  \
# 426619                 False              False                    0.00
# 26770                  False              False                   48.77
# 2447701                False              False                   23.78
# 95993                  False              False                   82.57
# 1485214                False              False                    0.00
#
#          (case) penalty_amount1  (case) penalty_amount2  \
# 426619                      NaN                     NaN
# 26770                       NaN                     NaN
# 2447701                     NaN                     NaN
# 95993                       NaN                     NaN
# 1485214                     NaN                     NaN
#
#          (case) penalty_amount3  (case) program-id  (case) redistribution  \
# 426619                      NaN                215                   True
# 26770                       NaN                215                   True
# 2447701                     NaN                215                   True
# 95993                       NaN                215                   True
# 1485214                     NaN                215                   True
#
#          (case) rejected  (case) risk_factor  (case) selected_manually  \
# 426619             False                 1.0                     False
# 26770              False                 1.0                     False
# 2447701            False                 1.0                     False
# 95993              False                 1.0                     False
# 1485214            False                 1.0                     False
#
#          (case) selected_random  (case) selected_risk  (case) small farmer  \
# 426619                    False                 False                False
# 26770                     False                 False                False
# 2447701                   False                 False                False
# 95993                     False                 False                False
# 1485214                   False                 False                False
#
#          (case) year  (case) young farmer        activity    concept:name  \
# 426619          2015                False       performed       performed
# 26770           2015                False  finish editing  finish editing
# 2447701         2017                False       calculate       calculate
# 95993           2015                False            save            save
# 1485214         2016                False  finish editing  finish editing
#
#                     docid                     doctype           eventid  \
# 426619   fe80053f34bfb8da  Department control parcels  fe80053f34bfb8e0
# 26770    ffc0054282399688     Entitlement application  ffc00542d51f40d4
# 2447701  ff40057d15b3b119         Payment application  ffc00580debc9154
# 95993    ffc00537d6f313dc             Control summary  fec0053eb9261360
# 1485214  ffc00555e02a0736         Geo parcel document  fec0055ab9d73960
#
#         lifecycle:transition       note   subprocess  success  \
# 426619              complete       none         Main     True
# 26770               complete  automatic         Main     True
# 2447701             complete  automatic  Application     True
# 95993               complete       none         Main     True
# 1485214             complete       none     Declared     True
#
#          num changes applied amount  final applied amount  \
# 426619                            0              11333.40
# 26770                             0               1505.57
# 2447701                           0              15636.07
# 95993                             0              62184.06
# 1485214                           0               3926.42
#
#          diff applied amount  applied amount lowered  applied amount changed  \
# 426619                   0.0                   False                   False
# 26770                    0.0                   False                   False
# 2447701                  0.0                   False                   False
# 95993                    0.0                   False                   False
# 1485214                  0.0                   False                   False
#
#          num changes actual amount  final actual amount  diff actual amount  \
# 426619                           0             11330.13                 0.0
# 26770                            0              1359.26                 0.0
# 2447701                          0             15596.69                 0.0
# 95993                            0             62080.09                 0.0
# 1485214                          0              3927.18                 0.0
#
#          actual amount lowered  actual amount changed  actual amount pay
# 426619                   False                  False              False
# 26770                    False                  False              False
# 2447701                  False                  False              False
# 95993                    False                  False              False
# 1485214                  False                  False              False

# %% [markdown]
# ### penalty amount processing

# %%
def return_final_penalty_amount(x):
    if not pd.isnull(x['(case) penalty_amount3']):
        return x['(case) penalty_amount3']
    elif not pd.isnull(x['(case) penalty_amount2']):
        return x['(case) penalty_amount2']
    elif not pd.isnull(x['(case) penalty_amount1']):
        return x['(case) penalty_amount1']
    else:
        return x['(case) penalty_amount0']

def return_num_changes_penalty_amount(x):
    result = 0
    if not (pd.isnull(x['(case) penalty_amount1']) or x['(case) penalty_amount0'] == x['(case) penalty_amount1']):
        result += 1
    if not (pd.isnull(x['(case) penalty_amount2']) or x['(case) penalty_amount1'] == x['(case) penalty_amount2']):
        result += 1
    if not (pd.isnull(x['(case) penalty_amount3']) or x['(case) penalty_amount2'] == x['(case) penalty_amount3']):
        result += 1
    return result

# %%
elog['num changes penalty amount'] = elog.apply(return_num_changes_penalty_amount, axis=1)
elog['final penalty amount'] = elog.apply(return_final_penalty_amount, axis=1)

# %%
elog['penalty amount applied'] = np.where(elog['final penalty amount'] > 0, True, False)

# %% [markdown]
# ### Penalty classification

# %%
penalty_reasons = ['(case) penalty_ABP', '(case) penalty_AGP', '(case) penalty_AJLP',
       '(case) penalty_AUVP', '(case) penalty_AVBP', '(case) penalty_AVGP',
       '(case) penalty_AVJLP', '(case) penalty_AVUVP',
       '(case) penalty_B16', '(case) penalty_B2', '(case) penalty_B3',
       '(case) penalty_B4', '(case) penalty_B5', '(case) penalty_B5F',
       '(case) penalty_B6', '(case) penalty_BGK', '(case) penalty_BGKV',
       '(case) penalty_BGP', '(case) penalty_C16', '(case) penalty_C4',
       '(case) penalty_C9', '(case) penalty_CC', '(case) penalty_GP1',
       '(case) penalty_JLP1', '(case) penalty_JLP2', '(case) penalty_JLP3',
       '(case) penalty_JLP5', '(case) penalty_JLP6', '(case) penalty_JLP7',
       '(case) penalty_V5']

# %%
# B3, B4, B5, B6, B16, BGK, C16, JLP3, V5
severe_penalties = ['(case) penalty_B3', '(case) penalty_B4', '(case) penalty_B5', '(case) penalty_B5F',
                    '(case) penalty_B6', '(case) penalty_B16', '(case) penalty_BGK', '(case) penalty_C16',
                    '(case) penalty_JLP3', '(case) penalty_V5']

# %%
def count_penalty_reasons(x):
    count = 0
    for reason in penalty_reasons:
        if x[reason]: # i.e. holds 'True'
            count += 1
    return count

# %%
def count_severe_penalties(x):
    count = 0
    for reason in severe_penalties:
        if x[reason]: # i.e. holds 'True'
            count += 1
    return count

# %%
elog['num_penalty_reasons'] = elog.apply(count_penalty_reasons, axis=1)

# %%
elog['num_severe_penalties'] = elog.apply(count_severe_penalties, axis=1)

# %%
len(set(elog['num_penalty_reasons']))
# Out:
# 8

# %%
len(set(elog['num_severe_penalties']))
# Out:
# 4

# %%
elog['penalty applied'] = np.where(elog['num_penalty_reasons'] > 0, True, False)

# %%
elog['severe penalty applied'] = np.where(elog['num_severe_penalties'] > 0, True, False)

# %%
elog.sample(3)
# Out:
#                   Case ID                                    Activity  \
# 1949653  50a0fe7a79db5739  Geo parcel document-Reported-begin editing
# 1697478  94de8aa3922f278e      Payment application-Application-decide
# 1358068  e92a03f80370582d               Geo parcel document-Main-save
#
#         Resource       Complete Timestamp  (case) amount_applied0  \
# 1949653   727350  2017/11/18 20:25:59.344                27670.90
# 1697478   4298e3  2017/12/11 15:41:23.796                32358.66
# 1358068   60b0b8  2016/11/09 13:03:39.480                26600.88
#
#          (case) amount_applied1  (case) amount_applied2  \
# 1949653                     NaN                     NaN
# 1697478                     NaN                     NaN
# 1358068                     NaN                     NaN
#
#          (case) amount_applied3  (case) applicant  (case) area  \
# 1949653                     NaN  7cc63f921a5b9371      93.1985
# 1697478                     NaN  57b4e3bf3d23dd88     110.6525
# 1358068                     NaN  532dcda55d46e5df      88.3559
#
#          (case) basic payment  (case) cross_compliance (case) department  \
# 1949653                  True                      0.0                4e
# 1697478                  True                      0.0                4e
# 1358068                  True                      0.0                4e
#
#          (case) greening  (case) number_parcels  (case) payment_actual0  \
# 1949653             True                     40                27662.44
# 1697478             True                     26                32348.76
# 1358068             True                     32                26611.28
#
#          (case) payment_actual1  (case) payment_actual2  \
# 1949653                     NaN                     NaN
# 1697478                     NaN                     NaN
# 1358068                     NaN                     NaN
#
#          (case) payment_actual3  (case) penalty_ABP  (case) penalty_AGP  \
# 1949653                     NaN               False               False
# 1697478                     NaN               False               False
# 1358068                     NaN               False               False
#
#          (case) penalty_AJLP  (case) penalty_AUVP  (case) penalty_AVBP  \
# 1949653                False                False                False
# 1697478                False                False                False
# 1358068                False                False                False
#
#          (case) penalty_AVGP  (case) penalty_AVJLP  (case) penalty_AVUVP  \
# 1949653                False                 False                 False
# 1697478                False                 False                 False
# 1358068                False                 False                 False
#
#          (case) penalty_B16  (case) penalty_B2  (case) penalty_B3  \
# 1949653               False              False              False
# 1697478               False              False              False
# 1358068               False              False              False
#
#          (case) penalty_B4  (case) penalty_B5  (case) penalty_B5F  \
# 1949653              False              False               False
# 1697478              False              False               False
# 1358068              False              False               False
#
#          (case) penalty_B6  (case) penalty_BGK  (case) penalty_BGKV  \
# 1949653              False               False                False
# 1697478              False               False                False
# 1358068              False               False                False
#
#          (case) penalty_BGP  (case) penalty_C16  (case) penalty_C4  \
# 1949653               False               False              False
# 1697478               False               False              False
# 1358068               False               False              False
#
#          (case) penalty_C9  (case) penalty_CC  (case) penalty_GP1  \
# 1949653              False              False               False
# 1697478              False              False               False
# 1358068              False              False               False
#
#          (case) penalty_JLP1  (case) penalty_JLP2  (case) penalty_JLP3  \
# 1949653                False                False                False
# 1697478                False                False                False
# 1358068                False                False                False
#
#          (case) penalty_JLP5  (case) penalty_JLP6  (case) penalty_JLP7  \
# 1949653                False                False                False
# 1697478                False                False                False
# 1358068                False                False                False
#
#          (case) penalty_V5  (case) penalty_amount0  (case) penalty_amount1  \
# 1949653              False                     0.0                     NaN
# 1697478              False                     0.0                     NaN
# 1358068              False                     0.0                     NaN
#
#          (case) penalty_amount2  (case) penalty_amount3  (case) program-id  \
# 1949653                     NaN                     NaN                215
# 1697478                     NaN                     NaN                215
# 1358068                     NaN                     NaN                215
#
#          (case) redistribution  (case) rejected  (case) risk_factor  \
# 1949653                   True            False                 1.0
# 1697478                   True            False                 1.0
# 1358068                   True            False                 1.0
#
#          (case) selected_manually  (case) selected_random  \
# 1949653                     False                   False
# 1697478                     False                   False
# 1358068                     False                   False
#
#          (case) selected_risk  (case) small farmer  (case) year  \
# 1949653                 False                False         2017
# 1697478                 False                False         2017
# 1358068                 False                False         2016
#
#          (case) young farmer       activity   concept:name             docid  \
# 1949653                False  begin editing  begin editing  ffc0056f03bc7c79
# 1697478                False         decide         decide  ff40057d15ba6a57
# 1358068                False           save           save  ffc00559c2b8d234
#
#                      doctype           eventid lifecycle:transition  \
# 1949653  Geo parcel document  ffc0057f1b6167da             complete
# 1697478  Payment application  fe40058107ee14e0             complete
# 1358068  Geo parcel document  fe80056112aee100             complete
#
#               note   subprocess  success  num changes applied amount  \
# 1949653  automatic     Reported     True                           0
# 1697478  automatic  Application     True                           0
# 1358068       none         Main     True                           0
#
#          final applied amount  diff applied amount  applied amount lowered  \
# 1949653              27670.90                  0.0                   False
# 1697478              32358.66                  0.0                   False
# 1358068              26600.88                  0.0                   False
#
#          applied amount changed  num changes actual amount  \
# 1949653                   False                          0
# 1697478                   False                          0
# 1358068                   False                          0
#
#          final actual amount  diff actual amount  actual amount lowered  \
# 1949653             27662.44                 0.0                  False
# 1697478             32348.76                 0.0                  False
# 1358068             26611.28                 0.0                  False
#
#          actual amount changed  actual amount pay  num changes penalty amount  \
# 1949653                  False              False                           0
# 1697478                  False              False                           0
# 1358068                  False              False                           0
#
#          final penalty amount  penalty amount applied  num_penalty_reasons  \
# 1949653                   0.0                   False                    0
# 1697478                   0.0                   False                    0
# 1358068                   0.0                   False                    0
#
#          num_severe_penalties  penalty applied  severe penalty applied
# 1949653                     0            False                   False
# 1697478                     0            False                   False
# 1358068                     0            False                   False

# %% [markdown]
# ### Assessing usefulness of the remaining set of attributes

# %% [markdown]
# #### program-id

# %%
len(set(elog['(case) program-id']))
# Out:
# 1

# %%
elog.drop(['(case) program-id'], axis=1, inplace=True)

# %% [markdown]
# #### risk_factor

# %%
set(elog['(case) risk_factor']) # leave as it is for now
# Out:
# {0.99, 1.0}

# %% [markdown]
# #### concept:name

# %%
elog['activity'].equals(elog['concept:name']) # so two columns with same infrormation, delete second one
# Out:
# True

# %%
elog.drop(['concept:name'], axis=1, inplace=True)

# %% [markdown]
# #### Activitiy = doctype + subprocess + activity?

# %%
elog['Activity'].equals(elog['doctype'].astype(str) + '-' + elog['subprocess'].astype(str) + '-' + elog['activity'].astype(str))
# Out:
# True

# %%
elog['Activity'].equals(elog['doctype'] + '-' + elog['subprocess'] + '-' + elog['activity'])
# Out:
# True

# %% [markdown]
# <i>Can remove "Activity" in the future since information is encapsulated in other attributes.</i>

# %% [markdown]
# #### lifecycle:transition

# %%
set(elog['lifecycle:transition'])
# Out:
# {'complete'}

# %%
elog.drop(['lifecycle:transition'], axis=1, inplace=True)

# %% [markdown]
# #### note

# %%
'none' in set(elog['note'])
# Out:
# True

# %%
np.nan in set (elog['note'])
# Out:
# True

# %%
elog.replace('none', np.nan, inplace=True)

# %%
'none' in set(elog['note'])
# Out:
# False

# %% [markdown]
# #### year

# %%
set(elog['(case) year'])
# Out:
# {2015, 2016, 2017}

# %%
elog.select_dtypes(include=[np.datetime64]).head(1) # so not a datetime object
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
elog['Complete Timestamp'] = pd.to_datetime(elog['Complete Timestamp'])

# %%
elog['(case) year'].equals(elog['Complete Timestamp'].map(lambda x: x.year))
# Out:
# False

# %%
elog['timestamp_year'] = elog['Complete Timestamp'].map(lambda x: x.year)

# %%
elog['timestamp_month'] = elog['Complete Timestamp'].map(lambda x: x.month)

# %%
elog.loc[elog['timestamp_year'] != elog['(case) year']].head(3)
# Out:
#               Case ID                                        Activity  \
# 51   8b99873a6136cfa6  Payment application-Application-finish payment
# 100  d038e6a5fcaed7a4  Payment application-Application-finish payment
# 101  d038e6a5fcaed7a4                   Reference alignment-Main-save
#
#     Resource      Complete Timestamp  (case) amount_applied0  \
# 51      DP-Z 2016-02-18 07:56:22.774                  960.35
# 100     DP-Z 2016-02-18 07:26:50.280                28192.23
# 101   167893 2017-02-13 14:19:13.000                28192.23
#
#      (case) amount_applied1  (case) amount_applied2  (case) amount_applied3  \
# 51                      NaN                     NaN                     NaN
# 100                     NaN                     NaN                     NaN
# 101                     NaN                     NaN                     NaN
#
#      (case) applicant  (case) area  (case) basic payment  \
# 51   b3b1bafcf8a5c359       2.6994                  True
# 100  ae8636c3e41e2eb1      93.5478                  True
# 101  ae8636c3e41e2eb1      93.5478                  True
#
#      (case) cross_compliance (case) department  (case) greening  \
# 51                       0.0                e7             True
# 100                      0.0                d4             True
# 101                      0.0                d4             True
#
#      (case) number_parcels  (case) payment_actual0  (case) payment_actual1  \
# 51                       3                  960.35                     NaN
# 100                     16                28170.75                     NaN
# 101                     16                28170.75                     NaN
#
#      (case) payment_actual2  (case) payment_actual3  (case) penalty_ABP  \
# 51                      NaN                     NaN               False
# 100                     NaN                     NaN               False
# 101                     NaN                     NaN               False
#
#      (case) penalty_AGP  (case) penalty_AJLP  (case) penalty_AUVP  \
# 51                False                False                False
# 100               False                False                False
# 101               False                False                False
#
#      (case) penalty_AVBP  (case) penalty_AVGP  (case) penalty_AVJLP  \
# 51                 False                False                 False
# 100                False                False                 False
# 101                False                False                 False
#
#      (case) penalty_AVUVP  (case) penalty_B16  (case) penalty_B2  \
# 51                  False               False              False
# 100                 False               False               True
# 101                 False               False               True
#
#      (case) penalty_B3  (case) penalty_B4  (case) penalty_B5  \
# 51               False              False              False
# 100              False              False              False
# 101              False              False              False
#
#      (case) penalty_B5F  (case) penalty_B6  (case) penalty_BGK  \
# 51                False              False               False
# 100               False              False               False
# 101               False              False               False
#
#      (case) penalty_BGKV  (case) penalty_BGP  (case) penalty_C16  \
# 51                 False               False               False
# 100                False               False               False
# 101                False               False               False
#
#      (case) penalty_C4  (case) penalty_C9  (case) penalty_CC  \
# 51               False              False              False
# 100              False              False              False
# 101              False              False              False
#
#      (case) penalty_GP1  (case) penalty_JLP1  (case) penalty_JLP2  \
# 51                False                False                False
# 100               False                False                False
# 101               False                False                False
#
#      (case) penalty_JLP3  (case) penalty_JLP5  (case) penalty_JLP6  \
# 51                 False                False                False
# 100                False                False                False
# 101                False                False                False
#
#      (case) penalty_JLP7  (case) penalty_V5  (case) penalty_amount0  \
# 51                 False              False                    0.00
# 100                False              False                   12.08
# 101                False              False                   12.08
#
#      (case) penalty_amount1  (case) penalty_amount2  (case) penalty_amount3  \
# 51                      NaN                     NaN                     NaN
# 100                     NaN                     NaN                     NaN
# 101                     NaN                     NaN                     NaN
#
#      (case) redistribution  (case) rejected  (case) risk_factor  \
# 51                    True            False                 1.0
# 100                   True            False                 1.0
# 101                   True            False                 1.0
#
#      (case) selected_manually  (case) selected_random  (case) selected_risk  \
# 51                      False                   False                 False
# 100                     False                   False                 False
# 101                     False                   False                 False
#
#      (case) small farmer  (case) year  (case) young farmer        activity  \
# 51                  True         2015                False  finish payment
# 100                False         2015                False  finish payment
# 101                False         2015                False            save
#
#                 docid              doctype           eventid  \
# 51   ffc0054364e897d9  Payment application  ffc0054bc318ec50
# 100  ffc0054364e02c74  Payment application  ffc0054bc3152338
# 101  ff40053afe90bbc4  Reference alignment  fe800568cea6d690
#
#                          note   subprocess  success  \
# 51   automatic during payment  Application     True
# 100  automatic during payment  Application     True
# 101                       NaN         Main     True
#
#      num changes applied amount  final applied amount  diff applied amount  \
# 51                            0                960.35                  0.0
# 100                           0              28192.23                  0.0
# 101                           0              28192.23                  0.0
#
#      applied amount lowered  applied amount changed  \
# 51                    False                   False
# 100                   False                   False
# 101                   False                   False
#
#      num changes actual amount  final actual amount  diff actual amount  \
# 51                           0               960.35                 0.0
# 100                          0             28170.75                 0.0
# 101                          0             28170.75                 0.0
#
#      actual amount lowered  actual amount changed  actual amount pay  \
# 51                   False                  False              False
# 100                  False                  False              False
# 101                  False                  False              False
#
#      num changes penalty amount  final penalty amount  penalty amount applied  \
# 51                            0                  0.00                   False
# 100                           0                 12.08                    True
# 101                           0                 12.08                    True
#
#      num_penalty_reasons  num_severe_penalties  penalty applied  \
# 51                     0                     0            False
# 100                    1                     0             True
# 101                    1                     0             True
#
#      severe penalty applied  timestamp_year  timestamp_month
# 51                    False            2016                2
# 100                   False            2016                2
# 101                   False            2017                2

# %%
elog.sample(3)
# Out:
#                   Case ID                                        Activity  \
# 2217980  147791e5a31442d2          Geo parcel document-Reported-calculate
# 501003   81e157f0e868f5ff             Reference alignment-Main-initialize
# 92771    91afbf7e2cb09657  Payment application-Application-finish payment
#
#                               Resource      Complete Timestamp  \
# 2217980                         727350 2017-12-08 00:26:25.543
# 501003   Reference alignment processor 2015-07-24 21:37:55.000
# 92771                             DP-Z 2016-02-18 07:51:17.064
#
#          (case) amount_applied0  (case) amount_applied1  \
# 2217980                 5117.97                     NaN
# 501003                 28192.23                     NaN
# 92771                  35415.64                     NaN
#
#          (case) amount_applied2  (case) amount_applied3  (case) applicant  \
# 2217980                     NaN                     NaN  66c82532d9662883
# 501003                      NaN                     NaN  531d6912f248d569
# 92771                       NaN                     NaN  d8950d3834ac6ee4
#
#          (case) area  (case) basic payment  (case) cross_compliance  \
# 2217980      13.3202                  True                      0.0
# 501003       93.5478                  True                      0.0
# 92771       102.7594                  True                      0.0
#
#         (case) department  (case) greening  (case) number_parcels  \
# 2217980                4e             True                      9
# 501003                 e7             True                     40
# 92771                  e7             True                     40
#
#          (case) payment_actual0  (case) payment_actual1  \
# 2217980                 5117.00                     NaN
# 501003                 28162.79                     NaN
# 92771                  35390.06                     NaN
#
#          (case) payment_actual2  (case) payment_actual3  (case) penalty_ABP  \
# 2217980                     NaN                     NaN               False
# 501003                      NaN                     NaN               False
# 92771                       NaN                     NaN               False
#
#          (case) penalty_AGP  (case) penalty_AJLP  (case) penalty_AUVP  \
# 2217980               False                False                False
# 501003                False                False                False
# 92771                 False                False                False
#
#          (case) penalty_AVBP  (case) penalty_AVGP  (case) penalty_AVJLP  \
# 2217980                False                False                 False
# 501003                 False                False                 False
# 92771                  False                False                 False
#
#          (case) penalty_AVUVP  (case) penalty_B16  (case) penalty_B2  \
# 2217980                 False               False              False
# 501003                  False               False               True
# 92771                   False               False               True
#
#          (case) penalty_B3  (case) penalty_B4  (case) penalty_B5  \
# 2217980              False              False              False
# 501003               False              False              False
# 92771                False              False              False
#
#          (case) penalty_B5F  (case) penalty_B6  (case) penalty_BGK  \
# 2217980               False              False               False
# 501003                False              False               False
# 92771                 False              False               False
#
#          (case) penalty_BGKV  (case) penalty_BGP  (case) penalty_C16  \
# 2217980                False               False               False
# 501003                 False               False               False
# 92771                  False               False               False
#
#          (case) penalty_C4  (case) penalty_C9  (case) penalty_CC  \
# 2217980              False              False              False
# 501003               False              False              False
# 92771                False              False              False
#
#          (case) penalty_GP1  (case) penalty_JLP1  (case) penalty_JLP2  \
# 2217980               False                False                False
# 501003                False                False                False
# 92771                 False                False                False
#
#          (case) penalty_JLP3  (case) penalty_JLP5  (case) penalty_JLP6  \
# 2217980                False                False                False
# 501003                 False                False                False
# 92771                  False                False                False
#
#          (case) penalty_JLP7  (case) penalty_V5  (case) penalty_amount0  \
# 2217980                False              False                    0.00
# 501003                 False              False                   20.12
# 92771                  False              False                   13.72
#
#          (case) penalty_amount1  (case) penalty_amount2  \
# 2217980                     NaN                     NaN
# 501003                      NaN                     NaN
# 92771                       NaN                     NaN
#
#          (case) penalty_amount3  (case) redistribution  (case) rejected  \
# 2217980                     NaN                   True            False
# 501003                      NaN                   True            False
# 92771                       NaN                   True            False
#
#          (case) risk_factor  (case) selected_manually  (case) selected_random  \
# 2217980                 1.0                     False                   False
# 501003                  1.0                     False                   False
# 92771                   1.0                     False                   False
#
#          (case) selected_risk  (case) small farmer  (case) year  \
# 2217980                 False                False         2017
# 501003                  False                False         2015
# 92771                   False                False         2015
#
#          (case) young farmer        activity             docid  \
# 2217980                 True       calculate  ffc005706276fe41
# 501003                 False      initialize  ff40053afe9551f0
# 92771                   True  finish payment  ffc0054364e84de0
#
#                      doctype           eventid                      note  \
# 2217980  Geo parcel document  ffc00580ca130bd4                 automatic
# 501003   Reference alignment  ff40053afe9551f0                       NaN
# 92771    Payment application  ffc0054bc3183d14  automatic during payment
#
#           subprocess  success  num changes applied amount  \
# 2217980     Reported     True                           0
# 501003          Main     True                           0
# 92771    Application     True                           0
#
#          final applied amount  diff applied amount  applied amount lowered  \
# 2217980               5117.97                  0.0                   False
# 501003               28192.23                  0.0                   False
# 92771                35415.64                  0.0                   False
#
#          applied amount changed  num changes actual amount  \
# 2217980                   False                          0
# 501003                    False                          0
# 92771                     False                          0
#
#          final actual amount  diff actual amount  actual amount lowered  \
# 2217980              5117.00                 0.0                  False
# 501003              28162.79                 0.0                  False
# 92771               35390.06                 0.0                  False
#
#          actual amount changed  actual amount pay  num changes penalty amount  \
# 2217980                  False              False                           0
# 501003                   False              False                           0
# 92771                    False              False                           0
#
#          final penalty amount  penalty amount applied  num_penalty_reasons  \
# 2217980                  0.00                   False                    0
# 501003                  20.12                    True                    1
# 92771                   13.72                    True                    1
#
#          num_severe_penalties  penalty applied  severe penalty applied  \
# 2217980                     0            False                   False
# 501003                      0             True                   False
# 92771                       0             True                   False
#
#          timestamp_year  timestamp_month
# 2217980            2017               12
# 501003             2015                7
# 92771              2016                2

# %%
elog.to_csv(dest_dir.__add__('elog').__add__(extension), index=False)
