# %%
import pandas as pd 
import numpy as np

# %%
import bitstring

# %%
source_dir = '../data/disco_to_csv/'
dest_dir = '../data/proc/'
extension = '.csv'

# %%
# Complete event log
elog = pd.read_csv(source_dir.__add__('BPI Challenge 2018.csv'))

# %%
# Subprocesses/documents
control_summary = pd.read_csv(source_dir.__add__('Control summary.csv'))
dep_control = pd.read_csv(source_dir.__add__('Department control parcels.csv'))
entitle_app = pd.read_csv(source_dir.__add__('Entitlement application.csv'))
geo_parcel = pd.read_csv(source_dir.__add__('Geo parcel document.csv'))
inspec = pd.read_csv(source_dir.__add__('Inspection.csv'))
parcel_doc = pd.read_csv(source_dir.__add__('Parcel document.csv'))
pay_app = pd.read_csv(source_dir.__add__('Payment application.csv'))
ref_align = pd.read_csv(source_dir.__add__('Reference alignment.csv'))

# %%
all_subprocess = [control_summary, dep_control, entitle_app, geo_parcel, inspec, parcel_doc, pay_app, ref_align]
all_proc = all_subprocess + [elog]

# %%
for sp in all_proc:
    sp.loc[sp['Resource'] == '0;n/a', 'Resource'] = np.NaN

# %%
for sp in all_subprocess:
    sp['Case ID'] = sp['Case ID'].apply(lambda x: x if np.isnan(x) else bitstring.BitArray('int:64=%d' % x).hex)

# %%
for sp in all_proc:
    sp['docid'] = sp['docid'].apply(lambda x: x if np.isnan(x) else bitstring.BitArray('int:64=%d' % x).hex)
    sp['eventid'] = sp['eventid'].apply(lambda x: x if np.isnan(x) else bitstring.BitArray('int:64=%d' % x).hex)

# %%
elog.head(3)
# Out:
#             Case ID                                     Activity Resource  \
# 0  8b99873a6136cfa6  Payment application-Application-mail income      NaN
# 1  8b99873a6136cfa6   Payment application-Application-mail valid      NaN
# 2  8b99873a6136cfa6      Entitlement application-Main-mail valid      NaN
#
#         Complete Timestamp       Variant  Variant index  \
# 0  2015/05/08 00:00:00.000  Variant 1832           1832
# 1  2015/05/08 00:00:00.000  Variant 1832           1832
# 2  2015/05/08 00:00:00.000  Variant 1832           1832
#
#    (case) amount_applied0  (case) amount_applied1  (case) amount_applied2  \
# 0                  960.35                     NaN                     NaN
# 1                  960.35                     NaN                     NaN
# 2                  960.35                     NaN                     NaN
#
#    (case) amount_applied3   ...    (case) young farmer     activity  \
# 0                     NaN   ...                  False  mail income
# ...

# %%
dep_control.head(3)
# Out:
#             Case ID                                   Activity Resource  \
# 0  fe80053f34cdb3f5  Department control parcels-Main-performed   727350
# 1  fe4005421a73f96a  Department control parcels-Main-performed   727350
# 2  fe80054350543512  Department control parcels-Main-performed   fb5fa8
#
#         Complete Timestamp    Variant  Variant index  (case) amount_applied0  \
# 0  2015/09/15 19:31:11.000  Variant 1              1                  960.35
# 1  2015/10/22 08:05:15.000  Variant 1              1                28192.23
# 2  2015/11/05 11:58:40.000  Variant 1              1                 6684.43
#
#    (case) amount_applied1  (case) amount_applied2  (case) amount_applied3  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
#
# ...

# %%
entitle_app.head(3)
# Out:
#             Case ID                                 Activity  \
# 0  ffc005428239d50b  Entitlement application-Main-mail valid
# 1  ffc005428239d50b  Entitlement application-Main-mail valid
# 2  ffc005428239d50b  Entitlement application-Main-initialize
#
#                         Resource       Complete Timestamp    Variant  \
# 0                            NaN  2015/05/08 00:00:00.000  Variant 5
# 1                            NaN  2015/05/08 00:00:00.000  Variant 5
# 2  Document processing automaton  2015/10/26 13:27:10.390  Variant 5
#
#    Variant index  (case) amount_applied0  (case) amount_applied1  \
# 0              5                  960.35                     NaN
# 1              5                  960.35                     NaN
# 2              5                  960.35                     NaN
#
#    (case) amount_applied2  (case) amount_applied3   ...     \
# 0                     NaN                     NaN   ...
# 1                     NaN                     NaN   ...
# ...

# %%
geo_parcel.head(3)
# Out:
#             Case ID                                     Activity  \
# 0  ffc00555e0372f63          Geo parcel document-Main-initialize
# 1  ffc00555e0372f63   Geo parcel document-Declared-begin editing
# 2  ffc00555e0372f63  Geo parcel document-Declared-finish editing
#
#                         Resource       Complete Timestamp    Variant  \
# 0  Document processing automaton  2016/06/22 15:51:03.862  Variant 7
# 1  Document processing automaton  2016/06/22 15:51:03.869  Variant 7
# 2  Document processing automaton  2016/06/22 15:51:04.929  Variant 7
#
#    Variant index  (case) amount_applied0  (case) amount_applied1  \
# 0              7                20652.65                     NaN
# 1              7                20652.65                     NaN
# 2              7                20652.65                     NaN
#
#    (case) amount_applied2  (case) amount_applied3   ...     \
# 0                     NaN                     NaN   ...
# ...

# %%
inspec.head(3)
# Out:
#             Case ID                      Activity              Resource  \
# 0  fe800539d0e93da7        Inspection-Remote-plan  Inspection automaton
# 1  fe800539d0e93da7  Inspection-Remote-initialize  Inspection automaton
# 2  fe800539d0e93da7        Inspection-Remote-save  Inspection automaton
#
#         Complete Timestamp     Variant  Variant index  (case) amount_applied0  \
# 0  2015/07/10 15:59:06.364  Variant 61             61                 1191.87
# 1  2015/07/10 15:59:06.364  Variant 61             61                 1191.87
# 2  2015/07/10 15:59:06.398  Variant 61             61                 1191.87
#
#    (case) amount_applied1  (case) amount_applied2  (case) amount_applied3  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
#
# ...

# %%
parcel_doc.head(3)
# Out:
#             Case ID                            Activity Resource  \
# 0  ff000537695e5fe8     Parcel document-Main-initialize   fb5fa8
# 1  ff000537695e5fe8  Parcel document-Main-begin editing   dde669
# 2  ff000537695e5fe8           Parcel document-Main-save   dde669
#
#         Complete Timestamp      Variant  Variant index  \
# 0  2015/06/10 11:16:28.000  Variant 698            698
# 1  2015/06/15 13:01:05.000  Variant 698            698
# 2  2015/06/15 13:01:25.000  Variant 698            698
#
#    (case) amount_applied0  (case) amount_applied1  (case) amount_applied2  \
# 0                  960.35                     NaN                     NaN
# 1                  960.35                     NaN                     NaN
# 2                  960.35                     NaN                     NaN
#
#    (case) amount_applied3   ...    (case) young farmer       activity  \
# 0                     NaN   ...                  False     initialize
# ...

# %%
pay_app.head(3)
# Out:
#             Case ID                                     Activity  \
# 0  ffc0054364e897d9  Payment application-Application-mail income
# 1  ffc0054364e897d9   Payment application-Application-mail valid
# 2  ffc0054364e897d9   Payment application-Application-initialize
#
#                         Resource       Complete Timestamp    Variant  \
# 0                            NaN  2015/05/08 00:00:00.000  Variant 8
# 1                            NaN  2015/05/08 00:00:00.000  Variant 8
# 2  Document processing automaton  2015/11/06 11:21:27.376  Variant 8
#
#    Variant index  (case) amount_applied0  (case) amount_applied1  \
# 0              8                  960.35                     NaN
# 1              8                  960.35                     NaN
# 2              8                  960.35                     NaN
#
#    (case) amount_applied2  (case) amount_applied3   ...     \
# 0                     NaN                     NaN   ...
# ...

# %%
ref_align.head(3)
# Out:
#             Case ID                             Activity  \
# 0  ff40053afe8ce5ea  Reference alignment-Main-initialize
# 1  ff40053afe8ce5ea   Reference alignment-Main-performed
# 2  ff40053afe90bbc4  Reference alignment-Main-initialize
#
#                         Resource       Complete Timestamp    Variant  \
# 0  Reference alignment processor  2015/07/24 21:10:08.000  Variant 1
# 1  Reference alignment processor  2015/07/24 21:10:08.000  Variant 1
# 2  Reference alignment processor  2015/07/24 21:22:19.000  Variant 2
#
#    Variant index  (case) amount_applied0  (case) amount_applied1  \
# 0              1                  960.35                     NaN
# 1              1                  960.35                     NaN
# 2              2                28192.23                     NaN
#
#    (case) amount_applied2  (case) amount_applied3   ...     \
# 0                     NaN                     NaN   ...
# 1                     NaN                     NaN   ...
# ...

# %%
 # ref_align['Case ID'] = ref_align['Case ID'].apply(lambda x: bitstring.BitArray('int:64=%d' % x).hex)

# %%
# bitstring.BitArray('int:64=54037444591557142').hex

# %%
# write back to csv files for further analysis/usage in other tools
for df in all_proc:
    df_name =  [k for k,v in locals().items() if df.equals(v)][0].__add__(extension) # file_name = var name + file extension
    df.to_csv(dest_dir.__add__(df_name), index=False)
